# %% [markdown]
# ## 5 number Summray and Box Plot

# %%
import numpy as np

# %%
lst_numbers = [67,89,99,78,56,34,78,67,23,45,34,76,86,45,67,89,90,12,34,56,150,1]

# %%
minimum, Q1, median, Q3, maximum = np.quantile(lst_numbers, [0, 0.25, 0.5, 0.75, 1])

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (1.0, 36.75, 67.0, 84.0, 150.0)

# %%
import seaborn as sns

# %%
sns.boxenplot(lst_numbers)
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: >
